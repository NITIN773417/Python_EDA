# %% [markdown]
# # 🧠 Exploratory Data Analysis: Nutrition Dataset
# This notebook performs a complete EDA process on the **Nutrition Dataset** dataset.

# %%
# 📥 Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 📊 Setting styles
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (12,6)

# 📂 Load the dataset
df = pd.read_csv("cleaned_nutrition_dataset.csv")

# 🔍 Preview the data
df.head()
# Out:
#    Vitamin C  Vitamin B11  Sodium  Calcium  Carbohydrates  \
# 0      0.082        0.086   0.018      2.8          0.073
# 1      0.400        0.005   0.065     10.2          3.700
# 2      0.000        0.000   0.000      0.0          0.000
# 3      0.000        0.000   0.000      0.0          0.000
# 4      0.000        0.000   0.000      0.0          0.000
#
#                      food   Iron  Caloric Value  Sugars  Dietary Fiber    Fat  \
# 0  margarine with yoghurt  0.027           88.0     0.0            0.0    9.8
# 1   sunflower seed butter  0.700           99.0     1.7            0.9    8.8
# 2            hazelnut oil  0.000          120.0     0.0            0.0   13.6
# 3       menhaden fish oil  0.000         1966.0     0.0            0.0  218.0
# 4      cod liver fish oil  0.000          123.0     0.0            0.0   13.6
#
#    Protein         food_normalized
# 0    0.058  margarine with yoghurt
# 1    2.800   sunflower seed butter
# 2    0.000            hazelnut oil
# 3    0.000       menhaden fish oil
# 4    0.000      cod liver fish oil

# %%
# 📋 Basic Info
print("Shape of dataset:", df.shape)
print("Data Types:", df.dtypes)
print("Missing Values:", df.isnull().sum())

# 📈 Descriptive Statistics
df.describe(include='all')
# Out:
# Shape of dataset: (3454, 13)
# Data Types: Vitamin C          float64
# Vitamin B11        float64
# Sodium             float64
# Calcium            float64
# Carbohydrates      float64
# food                object
# Iron               float64
# Caloric Value      float64
# Sugars             float64
# Dietary Fiber      float64
# Fat                float64
# Protein            float64
# food_normalized     object
# dtype: object
# Missing Values: Vitamin C          0
# Vitamin B11        0
# Sodium             0
# Calcium            0
# Carbohydrates      0
# food               0
# Iron               0
# Caloric Value      0
# Sugars             0
# Dietary Fiber      0
# Fat                0
# Protein            0
# food_normalized    0
# dtype: int64
#           Vitamin C  Vitamin B11        Sodium      Calcium  Carbohydrates  \
# count   3454.000000  3454.000000   3454.000000  3454.000000    3454.000000
# unique          NaN          NaN           NaN          NaN            NaN
# top             NaN          NaN           NaN          NaN            NaN
# freq            NaN          NaN           NaN          NaN            NaN
# mean       9.501021    11.447140    141.437806    53.953960      18.724570
# std       70.387542    33.849817    973.168394   103.339195      26.232674
# min        0.000000     0.000000      0.000000     0.000000       0.000000
# 25%        0.000000     0.029000      0.057000     4.647500       1.700000
# 50%        0.300000     0.075000      0.200000    21.940000       9.110000
# 75%        5.382500     4.327500     21.372500    60.600000      26.400000
# max     3872.000000   550.520000  14174.590000  1283.500000     390.200000
#
#                           food         Iron  Caloric Value       Sugars  \
# count                     3454  3454.000000    3454.000000  3454.000000
# unique                    3454          NaN            NaN          NaN
# top     margarine with yoghurt          NaN            NaN          NaN
# freq                         1          NaN            NaN          NaN
# mean                       NaN     1.627954     227.591546     5.693513
# std                        NaN     4.384574     336.277025    13.136356
# min                        NaN     0.000000       0.000000     0.000000
# 25%                        NaN     0.200000      60.050000     0.000000
# 50%                        NaN     0.700000     134.415000     0.920000
# 75%                        NaN     1.600000     285.007500     5.207500
# max                        NaN   121.200000    6077.000000   291.500000
#
#         Dietary Fiber          Fat      Protein  food_normalized
# count     3454.000000  3454.000000  3454.000000             3454
# unique            NaN          NaN          NaN             3432
# top               NaN          NaN          NaN  minestrone soup
# freq              NaN          NaN          NaN                2
# mean         2.157695    12.006807    10.819314              NaN
# std          4.748876    26.726515    27.250089              NaN
# min          0.000000     0.000000     0.000000              NaN
# 25%          0.000000     0.500000     1.262500              NaN
# 50%          0.710000     4.105000     3.800000              NaN
# 75%          2.327500    12.500000     9.242500              NaN
# max         76.500000   550.700000   560.300000              NaN

# %%
# 🔍 Univariate Analysis
df.hist(bins=20, figsize=(20, 15), color='skyblue')
plt.suptitle("Histograms of all Numerical Features", fontsize=20)
plt.show()

# %%
# 📊 Boxplots for detecting outliers
for column in df.select_dtypes(include=np.number).columns:
    plt.figure()
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ✅ Only keep numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# ✅ Generate Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %%
# 📑 Insights & Summary
print("✅ Dataset overview completed. Now based on the visuals and statistics above, we can draw insights regarding feature distribution, missing data, correlations, and potential outliers.")
# Out:
# ✅ Dataset overview completed. Now based on the visuals and statistics above, we can draw insights regarding feature distribution, missing data, correlations, and potential outliers.
