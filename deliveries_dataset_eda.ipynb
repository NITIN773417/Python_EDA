# %% [markdown]
# # 🧠 Exploratory Data Analysis: Deliveries Dataset
# This notebook performs a complete EDA process on the **Deliveries Dataset** dataset.

# %%
# 📥 Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 📊 Setting styles
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (12,6)

# 📂 Load the dataset
df = pd.read_csv("deliveries.csv")

# 🔍 Preview the data
df.head()
# Out:
#    match_no          date         stage                  venue batting_team  \
# 0         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 1         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 2         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 3         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 4         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
#
#   bowling_team  innings  over  striker     bowler  runs_of_bat  extras  wide  \
# 0          RCB        1   0.1  de Kock  Hazlewood            0       0     0
# 1          RCB        1   0.2  de Kock  Hazlewood            4       0     0
# 2          RCB        1   0.3  de Kock  Hazlewood            0       0     0
# 3          RCB        1   0.4  de Kock  Hazlewood            0       0     0
# 4          RCB        1   0.5  de Kock  Hazlewood            0       0     0
#
#    legbyes  byes  noballs wicket_type player_dismissed        fielder
# 0        0     0        0         NaN              NaN            NaN
# 1        0     0        0         NaN              NaN            NaN
# 2        0     0        0         NaN              NaN            NaN
# 3        0     0        0         NaN              NaN            NaN
# 4        0     0        0      caught          de Kock  Jitesh Sharma

# %%
# 📋 Basic Info
print("Shape of dataset:", df.shape)
print("Data Types:", df.dtypes)
print("Missing Values:", df.isnull().sum())

# 📈 Descriptive Statistics
df.describe(include='all')
# Out:
# Shape of dataset: (8028, 19)
# Data Types: match_no              int64
# date                 object
# stage                object
# venue                object
# batting_team         object
# bowling_team         object
# innings               int64
# over                float64
# striker              object
# bowler               object
# runs_of_bat           int64
# extras                int64
# wide                  int64
# legbyes               int64
# byes                  int64
# noballs               int64
# wicket_type          object
# player_dismissed     object
# fielder              object
# dtype: object
# Missing Values: match_no               0
# date                   0
# stage                  0
# venue                  0
# batting_team           0
# bowling_team           0
# innings                0
# over                   0
# striker                0
# bowler                 0
# runs_of_bat            0
# extras                 0
# wide                   0
# legbyes                0
# byes                   0
# noballs                0
# wicket_type         7606
# player_dismissed    7606
# fielder             7702
# dtype: int64
#            match_no          date         stage  \
# count   8028.000000          8028          8028
# unique          NaN            28             1
# top             NaN  Apr 08, 2025  League stage
# freq            NaN           512          8028
# mean      17.323368           NaN           NaN
# std        9.733451           NaN           NaN
# min        1.000000           NaN           NaN
# 25%        9.000000           NaN           NaN
# 50%       17.000000           NaN           NaN
# 75%       26.000000           NaN           NaN
# max       34.000000           NaN           NaN
#
#                                                     venue batting_team  \
# count                                                8028         8028
# unique                                                 12           10
# top     Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...           RR
# freq                                                  979          878
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        bowling_team      innings         over        striker         bowler  \
# count          8028  8028.000000  8028.000000           8028           8028
# unique           10          NaN          NaN            131             99
# top              RR          NaN          NaN  Sai Sudharsan  Digvesh Rathi
# freq            868          NaN          NaN            233            174
# mean            NaN     1.480942     9.397172            NaN            NaN
# std             NaN     0.504136     5.619690            NaN            NaN
# min             NaN     1.000000     0.100000            NaN            NaN
# 25%             NaN     1.000000     4.500000            NaN            NaN
# 50%             NaN     1.000000     9.300000            NaN            NaN
# 75%             NaN     2.000000    14.200000            NaN            NaN
# max             NaN     4.000000    19.600000            NaN            NaN
#
#         runs_of_bat       extras         wide      legbyes         byes  \
# count   8028.000000  8028.000000  8028.000000  8028.000000  8028.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       1.433732     0.072372     0.040982     0.010837     0.002367
# std        1.801669     0.353126     0.198260     0.103542     0.048594
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        0.000000     0.000000     0.000000     0.000000     0.000000
# 50%        1.000000     0.000000     0.000000     0.000000     0.000000
# 75%        2.000000     0.000000     0.000000     0.000000     0.000000
# max        6.000000     5.000000     1.000000     1.000000     1.000000
#
#             noballs wicket_type player_dismissed        fielder
# count   8028.000000         422              422            326
# unique          NaN           7              119            136
# top             NaN      caught          Jaiswal  Jitesh Sharma
# freq            NaN         294                8             10
# mean       0.003861         NaN              NaN            NaN
# std        0.062025         NaN              NaN            NaN
# min        0.000000         NaN              NaN            NaN
# 25%        0.000000         NaN              NaN            NaN
# 50%        0.000000         NaN              NaN            NaN
# 75%        0.000000         NaN              NaN            NaN
# max        1.000000         NaN              NaN            NaN

# %%
# 🔍 Univariate Analysis
df.hist(bins=20, figsize=(20, 15), color='skyblue')
plt.suptitle("Histograms of all Numerical Features", fontsize=20)
plt.show()

# %%
# 📊 Boxplots for detecting outliers
for column in df.select_dtypes(include=np.number).columns:
    plt.figure()
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
# 🔗 Correlation Heatmap (for numeric columns only)
numeric_df = df.select_dtypes(include=[np.number])  # filters only numeric columns
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %%
# 📑 Insights & Summary
print("✅ Dataset overview completed. Now based on the visuals and statistics above, we can draw insights regarding feature distribution, missing data, correlations, and potential outliers.")
# Out:
# ✅ Dataset overview completed. Now based on the visuals and statistics above, we can draw insights regarding feature distribution, missing data, correlations, and potential outliers.
