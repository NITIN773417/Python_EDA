# %% [markdown]
# # 🧠 Exploratory Data Analysis: Diabetes Dataset
# This notebook performs a complete EDA process on the **Diabetes Dataset** dataset.

# %%
# 📥 Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 📊 Setting styles
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (12,6)

# 📂 Load the dataset
df = pd.read_csv("diabetes_dataset.csv")

# 🔍 Preview the data
df.head()
# Out:
#    Unnamed: 0  Age     Sex Ethnicity   BMI  Waist_Circumference  \
# 0           0   58  Female     White  35.8                 83.4
# 1           1   48    Male     Asian  24.1                 71.4
# 2           2   34  Female     Black  25.0                113.8
# 3           3   62    Male     Asian  32.7                100.4
# 4           4   27  Female     Asian  33.5                110.8
#
#    Fasting_Blood_Glucose  HbA1c  Blood_Pressure_Systolic  \
# 0                  123.9   10.9                      152
# 1                  183.7   12.8                      103
# 2                  142.0   14.5                      179
# 3                  167.4    8.8                      176
# 4                  146.4    7.1                      122
#
#    Blood_Pressure_Diastolic  ...  Cholesterol_HDL  Cholesterol_LDL   GGT  \
# 0                       114  ...             50.2             99.2  37.5
# 1                        91  ...             62.0            146.4  88.5
# 2                       104  ...             32.1            164.1  56.2
# 3                       118  ...             41.1             84.0  34.4
# 4                        97  ...             53.9             92.8  81.9
#
#    Serum_Urate  Physical_Activity_Level Dietary_Intake_Calories  \
# 0          7.2                 Moderate                    1538
# 1          6.1                 Moderate                    2653
# 2          6.9                      Low                    1684
# 3          5.4                      Low                    3796
# 4          7.4                 Moderate                    3161
#
#    Alcohol_Consumption Smoking_Status Family_History_of_Diabetes  \
# 0             Moderate          Never                          0
# 1             Moderate        Current                          0
# 2                Heavy         Former                          1
# 3             Moderate          Never                          1
# 4                Heavy        Current                          0
#
#    Previous_Gestational_Diabetes
# 0                              1
# 1                              1
# 2                              0
# 3                              0
# 4                              0
#
# [5 rows x 21 columns]

# %%
# 📋 Basic Info
print("Shape of dataset:", df.shape)
print("Data Types:", df.dtypes)
print("Missing Values:", df.isnull().sum())

# 📈 Descriptive Statistics
df.describe(include='all')
# Out:
# Shape of dataset: (10000, 21)
# Data Types: Unnamed: 0                         int64
# Age                                int64
# Sex                               object
# Ethnicity                         object
# BMI                              float64
# Waist_Circumference              float64
# Fasting_Blood_Glucose            float64
# HbA1c                            float64
# Blood_Pressure_Systolic            int64
# Blood_Pressure_Diastolic           int64
# Cholesterol_Total                float64
# Cholesterol_HDL                  float64
# Cholesterol_LDL                  float64
# GGT                              float64
# Serum_Urate                      float64
# Physical_Activity_Level           object
# Dietary_Intake_Calories            int64
# Alcohol_Consumption               object
# Smoking_Status                    object
# Family_History_of_Diabetes         int64
# Previous_Gestational_Diabetes      int64
# dtype: object
# Missing Values: Unnamed: 0                          0
# Age                                 0
# Sex                                 0
# Ethnicity                           0
# BMI                                 0
# Waist_Circumference                 0
# Fasting_Blood_Glucose               0
# HbA1c                               0
# Blood_Pressure_Systolic             0
# Blood_Pressure_Diastolic            0
# Cholesterol_Total                   0
# Cholesterol_HDL                     0
# Cholesterol_LDL                     0
# GGT                                 0
# Serum_Urate                         0
# Physical_Activity_Level             0
# Dietary_Intake_Calories             0
# Alcohol_Consumption              3320
# Smoking_Status                      0
# Family_History_of_Diabetes          0
# Previous_Gestational_Diabetes       0
# dtype: int64
#          Unnamed: 0           Age     Sex Ethnicity           BMI  \
# count   10000.00000  10000.000000   10000     10000  10000.000000
# unique          NaN           NaN       2         4           NaN
# top             NaN           NaN  Female     Black           NaN
# freq            NaN           NaN    5005      2539           NaN
# mean     4999.50000     44.620400     NaN       NaN     29.418150
# std      2886.89568     14.343489     NaN       NaN      6.170866
# min         0.00000     20.000000     NaN       NaN     18.500000
# 25%      2499.75000     32.000000     NaN       NaN     24.100000
# 50%      4999.50000     45.000000     NaN       NaN     29.500000
# 75%      7499.25000     57.000000     NaN       NaN     34.700000
# max      9999.00000     69.000000     NaN       NaN     40.000000
#
#         Waist_Circumference  Fasting_Blood_Glucose         HbA1c  \
# count           10000.00000           10000.000000  10000.000000
# unique                  NaN                    NaN           NaN
# top                     NaN                    NaN           NaN
# freq                    NaN                    NaN           NaN
# mean               94.79707             134.776210      9.507510
# std                14.38329              37.633544      3.176421
# min                70.00000              70.000000      4.000000
# 25%                82.20000             102.175000      6.800000
# 50%                94.90000             134.500000      9.500000
# 75%               107.00000             167.800000     12.300000
# max               120.00000             200.000000     15.000000
#
#         Blood_Pressure_Systolic  Blood_Pressure_Diastolic  ...  \
# count              10000.000000              10000.000000  ...
# unique                      NaN                       NaN  ...
# top                         NaN                       NaN  ...
# freq                        NaN                       NaN  ...
# mean                 134.163700                 89.558700  ...
# std                   26.110317                 17.237792  ...
# min                   90.000000                 60.000000  ...
# 25%                  112.000000                 75.000000  ...
# 50%                  134.000000                 89.000000  ...
# 75%                  157.000000                105.000000  ...
# max                  179.000000                119.000000  ...
#
#         Cholesterol_HDL  Cholesterol_LDL          GGT   Serum_Urate  \
# count      10000.000000      10000.00000  10000.00000  10000.000000
# unique              NaN              NaN          NaN           NaN
# top                 NaN              NaN          NaN           NaN
# freq                NaN              NaN          NaN           NaN
# mean          55.019340        134.35377     55.16822      5.503430
# std           14.537371         37.50238     25.88180      1.455091
# min           30.000000         70.00000     10.00000      3.000000
# 25%           42.300000        101.67500     32.60000      4.200000
# 50%           55.200000        134.40000     55.45000      5.500000
# 75%           67.900000        166.40000     77.50000      6.800000
# max           80.000000        200.00000    100.00000      8.000000
#
#         Physical_Activity_Level Dietary_Intake_Calories  Alcohol_Consumption  \
# count                     10000            10000.000000                 6680
# unique                        3                     NaN                    2
# top                         Low                     NaN             Moderate
# freq                       3372                     NaN                 3373
# mean                        NaN             2742.481900                  NaN
# std                         NaN              716.643803                  NaN
# min                         NaN             1500.000000                  NaN
# 25%                         NaN             2129.000000                  NaN
# 50%                         NaN             2727.000000                  NaN
# 75%                         NaN             3368.000000                  NaN
# max                         NaN             3999.000000                  NaN
#
#        Smoking_Status Family_History_of_Diabetes  \
# count           10000               10000.000000
# unique              3                        NaN
# top           Current                        NaN
# freq             3364                        NaN
# mean              NaN                   0.507000
# std               NaN                   0.499976
# min               NaN                   0.000000
# 25%               NaN                   0.000000
# 50%               NaN                   1.000000
# 75%               NaN                   1.000000
# max               NaN                   1.000000
#
#         Previous_Gestational_Diabetes
# count                    10000.000000
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean                         0.516500
# std                          0.499753
# min                          0.000000
# 25%                          0.000000
# 50%                          1.000000
# 75%                          1.000000
# max                          1.000000
#
# [11 rows x 21 columns]

# %%
# 🔍 Univariate Analysis
df.hist(bins=20, figsize=(20, 15), color='skyblue')
plt.suptitle("Histograms of all Numerical Features", fontsize=20)
plt.show()

# %%
# 📊 Boxplots for detecting outliers
for column in df.select_dtypes(include=np.number).columns:
    plt.figure()
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
# ✅ Select only numeric columns before computing correlation
numeric_df = df.select_dtypes(include=[np.number])

# ✅ Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %%
# 📑 Insights & Summary
print("✅ Dataset overview completed. Now based on the visuals and statistics above, we can draw insights regarding feature distribution, missing data, correlations, and potential outliers.")
# Out:
# ✅ Dataset overview completed. Now based on the visuals and statistics above, we can draw insights regarding feature distribution, missing data, correlations, and potential outliers.
